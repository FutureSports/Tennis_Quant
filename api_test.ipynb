# %%
import requests

# Use your actual token here
access_token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjRYa0U1VDZRZkFpMFFaZnRRaFQweiJ9..ZMHIsFhcokrON6TC-gOVoOq1tE0StonaDsGCeQnC1G60FhWQcLMYGWO6esRfCzruH8FnGPCLS_QVHYq4EmblfV7y7Z3H7X4Slyfw1VU1Tv2pQ1dIXujvXLJ6-lfEq83bA7JtOU6sbsd3RC2zavdsK3EQqiP2WvGM1rhxiAIcIjaLMMfQLRsl85-zCGRZ51f24u-zueR4U2NHPFEpbW6LQwqt15xVsVURB1HMRAncMGs6L7_gXOP8CClcc1n82XhfRoPA6CuZsqh2iCQ8IlV5Zse4Yz5ee_dwA2rBa50-dtR1DMg0IG-HopriZMiFjt0hn9jVSNi9DDENGZ2cUupBrA"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# Example GraphQL query
graphql_query = {
    "query": """
    {
      players(limit: 300) {
        items {
          active
          age
          associationId
          backhandStyle
          birthCity
          birthDate
          careerPrizeMoney
          coach
          doublesCareerLosses
          doublesCareerTitles
          doublesCareerWins
          doublesHighestRank
          doublesHighestRankDate
          doublesLossesYearToDate
          doublesRank
          doublesTitlesYearToDate
          doublesWinsYearToDate
          firstName
          handedness
          heightCm
          heightFt
          id
          lastName
          nationality
          natlId
          playerHeadshotUrl
          residence
          singlesCareerLosses
          singlesCareerTitles
          singlesCareerWins
          singlesHighestRank
          singlesHighestRankDate
          singlesLossesYearToDate
          singlesRank
          singlesTitlesYearToDate
          singlesWinsYearToDate
          weightKg
          weightLb
          yearToDatePrizeMoney
          yearTurnedPro
        }
      }
    }
    """
}

response = requests.post(
    "https://graph-api.atp.data.tennis/graphql",  # or UAT endpoint
    headers=headers,
    json=graphql_query
)

print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
import requests
import pandas as pd

# Use your actual token here
access_token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjRYa0U1VDZRZkFpMFFaZnRRaFQweiJ9..ZMHIsFhcokrON6TC-gOVoOq1tE0StonaDsGCeQnC1G60FhWQcLMYGWO6esRfCzruH8FnGPCLS_QVHYq4EmblfV7y7Z3H7X4Slyfw1VU1Tv2pQ1dIXujvXLJ6-lfEq83bA7JtOU6sbsd3RC2zavdsK3EQqiP2WvGM1rhxiAIcIjaLMMfQLRsl85-zCGRZ51f24u-zueR4U2NHPFEpbW6LQwqt15xVsVURB1HMRAncMGs6L7_gXOP8CClcc1n82XhfRoPA6CuZsqh2iCQ8IlV5Zse4Yz5ee_dwA2rBa50-dtR1DMg0IG-HopriZMiFjt0hn9jVSNi9DDENGZ2cUupBrA"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

graphql_query = {
    "query": """
    {
      players(limit: 300) {
        items {
          active
          age
          associationId
          backhandStyle
          birthCity
          birthDate
          careerPrizeMoney
          coach
          doublesCareerLosses
          doublesCareerTitles
          doublesCareerWins
          doublesHighestRank
          doublesHighestRankDate
          doublesLossesYearToDate
          doublesRank
          doublesTitlesYearToDate
          doublesWinsYearToDate
          firstName
          handedness
          heightCm
          heightFt
          id
          lastName
          nationality
          natlId
          playerHeadshotUrl
          residence
          singlesCareerLosses
          singlesCareerTitles
          singlesCareerWins
          singlesHighestRank
          singlesHighestRankDate
          singlesLossesYearToDate
          singlesRank
          singlesTitlesYearToDate
          singlesWinsYearToDate
          weightKg
          weightLb
          yearToDatePrizeMoney
          yearTurnedPro
        }
      }
    }
    """
}

response = requests.post(
    "https://graph-api.atp.data.tennis/graphql",
    headers=headers,
    json=graphql_query
)

# Handle response and export to CSV
try:
    json_data = response.json()
    players = json_data.get("data", {}).get("players", {}).get("items", [])

    if players:
        df = pd.DataFrame(players)
        df.to_csv("players_full_300.csv", index=False)
        print("✅ Exported 300 players to 'players_full_300.csv'")
    else:
        print("❌ No player data returned:")
        print(json_data)
except Exception as e:
    print("❌ Error:", str(e))
    print("Raw response:", response.text)
# Out:
# ✅ Exported 300 players to 'players_full_300.csv'

# %%
# Handle response and export to CSV
https://graph-uat.tdi-sdp-dev.championdata.io/graphql
https://graph-uat.tdi-sdp-dev.championdata.io/graphql
# Out:
# ✅ Exported 300 players to 'players_full_300.csv'

# %%
import requests

access_token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjRYa0U1VDZRZkFpMFFaZnRRaFQweiJ9..ZMHIsFhcokrON6TC-gOVoOq1tE0StonaDsGCeQnC1G60FhWQcLMYGWO6esRfCzruH8FnGPCLS_QVHYq4EmblfV7y7Z3H7X4Slyfw1VU1Tv2pQ1dIXujvXLJ6-lfEq83bA7JtOU6sbsd3RC2zavdsK3EQqiP2WvGM1rhxiAIcIjaLMMfQLRsl85-zCGRZ51f24u-zueR4U2NHPFEpbW6LQwqt15xVsVURB1HMRAncMGs6L7_gXOP8CClcc1n82XhfRoPA6CuZsqh2iCQ8IlV5Zse4Yz5ee_dwA2rBa50-dtR1DMg0IG-HopriZMiFjt0hn9jVSNi9DDENGZ2cUupBrA"

headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

introspection_query = {
    "query": """
    {
      __schema {
        queryType {
          name
        }
        types {
          name
          kind
          fields {
            name
          }
        }
      }
    }
    """
}

response = requests.post(
    "https://graph-uat.tdi-sdp-dev.championdata.io/graphql",
    headers=headers,
    json=introspection_query
)

if response.status_code == 200:
    schema_data = response.json()
    # Display just a sample of the types and fields
    for t in schema_data["data"]["__schema"]["types"][:10]:  # first 10 types
        print(f"Type: {t['name']}")
        if t.get("fields"):
            for f in t["fields"]:
                print(f"  Field: {f['name']}")
else:
    print("Failed to fetch schema")
    print(response.status_code, response.text)
# Out:
# Type: Query
#   Field: decodedChairUmpireMatchStatistics
#   Field: decodedTennisVizInsights
#   Field: decodedTennisVizMomentum
#   Field: decodedChairUmpireFeedMessages
#   Field: matches
#   Field: match
#   Field: matchByAssociationId
#   Field: matchEvents
#   Field: matchEventsByAssociationId
#   Field: matchHealthCheck
#   Field: matchStatistics
#   Field: player
#   Field: players
#   Field: subscriptionLog
#   Field: playerInsightsAverages
#   Field: tournament
#   Field: tournamentHealthCheck
#   Field: tournaments
#   Field: tournamentByAssociationId
#   Field: umpire
#   Field: umpires
#   Field: decodedTennisVizL2
# Type: DecodedChairUmpireMatchStats
#   Field: TournamentYear
#   Field: TournamentId
#   Field: MatchId
#   Field: Status
#   Field: PlayerTeam1
#   Field: PlayerTeam2
# Type: Int
# Type: String
# Type: MatchStatsPlayerTeam
#   Field: PlayerId
#   Field: PartnerId
#   Field: GamePointsPlayerTeam
#   Field: Sets
# Type: MatchStatsSet
#   Field: SetNumber
# ...
